# %% [markdown]
# # Web scraper for accessibledictionary.gov.bd

# %% [markdown]
# ##### import necessary libraries

# %%
from bs4 import BeautifulSoup as bs
import requests
from tqdm import tqdm
import re

# %% [markdown]
# #### Load "Bengali to Enlish" dictionary 1st page
# there are several pages

# %%
site="https://accessibledictionary.gov.bd/bengali-to-english/?alp=%E0%A6%85"
r=requests.get(site)

#convert to a beautiful soup object

soup = bs(r.content)

#print out the HTML

contents = soup.prettify()

# print(contents)

# %% [markdown]
# ##### Getting all the link of all the banlga alphabets from অ to হ

# %%
alphabet_links=[]
alphabet_box =soup.find(class_="alphabet")
alphs=alphabet_box.find_all('a')
for index,row in enumerate(alphs):
    link=row.get('href')
#     print(link)
    alphabet_links.append(link)

alphabet_links
# Out:
# ['https://accessibledictionary.gov.bd/bengali-to-english/?alp=অ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=আ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ই',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঈ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=উ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঊ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঋ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=এ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঐ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ও',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঔ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ক',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=খ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=গ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঘ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঙ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=চ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ছ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=জ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঝ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঞ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ট',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঠ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ড',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঢ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ণ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ত',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=থ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=দ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ধ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ন',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=প',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ফ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ব',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ভ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ম',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=য',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=র',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ল',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=শ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ষ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=স',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=হ']

# %% [markdown]
# ##### getting page numbers for each alphabet

# %%
''' alph_and_page_numbers_info dictionary 
    key= link of each alphabet
    value= number of pages available for that alphabet(int)
'''
alph_and_page_numbers_info={}

# pagitation_box=soup.find(class_="pagination")
# page_numbers=pagitation_box.find_all('li')
# page_numbers[-2].get_text()
for index,link in enumerate(alphabet_links):
    r=requests.get(link)
    soup = bs(r.content)
    
    if soup.find(class_="pagination"):
        
        pagitation_box=soup.find(class_="pagination")
        page_numbers=pagitation_box.find_all('li')

        no_of_pages=int(page_numbers[-2].get_text())
    else:
        no_of_pages=1
    alph_and_page_numbers_info [link] =no_of_pages
    
    print(f"Case no: {index}: done")
    
alph_and_page_numbers_info
# Out:
# Case no: 0: done
# Case no: 1: done
# Case no: 2: done
# Case no: 3: done
# Case no: 4: done
# Case no: 5: done
# Case no: 6: done
# Case no: 7: done
# Case no: 8: done
# Case no: 9: done
# Case no: 10: done
# Case no: 11: done
# Case no: 12: done
# Case no: 13: done
# Case no: 14: done
# Case no: 15: done
# Case no: 16: done
# Case no: 17: done
# Case no: 18: done
# Case no: 19: done
# Case no: 20: done
# Case no: 21: done
# Case no: 22: done
# Case no: 23: done
# Case no: 24: done
# Case no: 25: done
# Case no: 26: done
# Case no: 27: done
# Case no: 28: done
# Case no: 29: done
# Case no: 30: done
# Case no: 31: done
# Case no: 32: done
# Case no: 33: done
# Case no: 34: done
# Case no: 35: done
# Case no: 36: done
# Case no: 37: done
# Case no: 38: done
# Case no: 39: done
# Case no: 40: done
# Case no: 41: done
# Case no: 42: done
# {'https://accessibledictionary.gov.bd/bengali-to-english/?alp=অ': 48,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=আ': 30,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ই': 7,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঈ': 1,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=উ': 16,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঊ': 1,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঋ': 1,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=এ': 13,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঐ': 1,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ও': 3,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঔ': 1,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ক': 46,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=খ': 11,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=গ': 18,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঘ': 6,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঙ': 1,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=চ': 19,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ছ': 8,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=জ': 26,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঝ': 5,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঞ': 1,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ট': 6,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঠ': 3,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ড': 4,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঢ': 3,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ণ': 1,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ত': 27,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=থ': 2,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=দ': 33,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ধ': 11,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ন': 44,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=প': 100,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ফ': 14,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ব': 86,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ভ': 23,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ম': 49,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=য': 10,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=র': 21,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ল': 17,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=শ': 25,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ষ': 1,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=স': 87,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=হ': 22}

# %% [markdown]
# ##### Getting contents for a single alphabet: অ

# %%
alph=alphabet_links[0][-1]
print(alph)
page=1


site=f"https://accessibledictionary.gov.bd/bengali-to-english/?alp={alph}&page={page}"

dictionary_info={}

r=requests.get(site)
soup = bs(r.content)

# print(soup.title.get_text()

article_box=soup.find(class_="dicDisplay")
word_list=article_box.find("ul")
words=word_list.find_all("li")
for w in words:
    
    print(w.text,end="\n\n\n")
# Out:
# অ
# Bengali Word অ ১English definition(noun) the written form of the first vowel sound and 1st letter of the Bengali alphabet. Unlike other vowels অ has no shortened sign (like া ি ী). অ-আ, অ-আ-ক-খ (noun(s))
# 1 the letters of the Bengali alphabet.
# 2 elementary knowledge; the rudiments of learning; ABC: ব্যাকরণের অ-আ-ক-খ.
#
#
# Bengali Word অ ২English definition(prefix) used before (noun(s)), (adjective(s)) and (adverb(s)), it indicates negation, absence, want, shortage, contrariety,  and hostility (eg অবাঙালি, অকারণ, অযত্ন, অপরিণত, অঘাট, অধর্ম) and is equivalent to various negative prefixes in English, ie, non-, un-, il-, im-, in-, ir-, dis-, mis-, etc; when prefixed by a word beginning with a vowel, অ is replaced by অন, eg অ+অভিজ্ঞ = অনভিজ্ঞ, অ + ঐক্য=অনৈক্য, অ+ঊর্বর = অনূর্বর, etc.
#
#
# Bengali Word অংশEnglish definition(noun) 1 portion or piece of a whole; a section; a constituent or organic part: দেহের অর্ধাংশ (অর্ধ+অংশ); যন্ত্রের অংশ (যন্ত্রাংশ); শহরের পশ্চিমাংশ (পশ্চিম+অংশ); সমাজের বুদ্ধিজীবী অংশ, the intellectual section of the society.
# 2 an incomplete portion; a fragment or decimal fraction: ভগ্নাংশ
# (ভগ্ন+অংশ) (1/5, 0.20).
# 3 a region or geographical division: পার্বত্য অংশ.
# 4 a share or allotment: সম্পত্তির অংশ, কারবারের অংশ.
# 5 (geography) 1/360th part of the earth’s circumference; a degree: অক্ষের অংশ (অক্ষাংশ).
# 6 (astrology) 1/12th part or one of the 12 signs of the zodiac: রাশিচক্রের অংশ (রাশি).
# 7 begetting power of male deities: অবতার দেবতার অংশে জাত, an Avatara is begotten/born of a god.
# 8 incarnation or personation: বিষ্ণুর অংশ রূপে ধরাধামে আবির্ভূত, incarnation of Vishnu on earth.
# 9 point(s) of consideration; any aspect(s) of something: কোনো কোনো অংশে, in some respects.
# অংশক (noun)(algebra) fractional part of a logarithm; a mantissa; a kinsman; a day.
# অংশ করা (verb intransitive), (verb transitive) divide into parts or shares; distribute.
# অংশগত (adjective) included in the rightful or inherited share; relating to a share or portion.
# অংশগ্রহণ (noun) taking part; participation.
# অংশগ্রহণ করা (verb intransitive), (verb transitive) take part/participate (in).
# অংশগ্রাহী (adjective) taking a share; sharing; participating.
# (noun)  co-sharer; Shareholder; participant; a party.
# অংশত (adverb) in part; partly; partially: অংশত দায়ী.
# অংশন (noun) act of dividing/apportioning; apportionment.
# অংশনামা (noun) a deed of partition.
# অংশনীয় (adjective) divisible into parts or shares; to be divided.
# অংশভাগী (adjective) having a claim to a share; entitled to a share.
#
#
# Bengali Word অংশাংশ English definition(noun) 1 fraction of a share.
#  2 different shares.
#
#
# Bengali Word অংশাংশি, অংশা-অংশি English definition(noun) division into respective shares.
# (adverb) according to respective shares; part by part.
#
#
# Bengali Word অংশানোEnglish definition(verb intransitive) (verb transitive) descend/devolve on as an inheritance.
#
#
# Bengali Word অংশিতEnglish definition(adjective) divided into parts or shares; partitioned.
#
#
# Bengali Word অংশীEnglish definition(adjective) constituted (or composed) of parts.
# (noun) 1 one who shares (the sorrows of) or feels (pity for): আমার দুঃখের অংশী.
# 2 an associate in business or ownership; partner; co-sharer; shareholder; party; participant.
# অংশীদার (noun) one having a share in a property or business.
# অংশীদারি (noun) partnership.
# (adjective) relating to partnership.
#
#
# Bengali Word অংশু English definition(noun) 1 ray of light; beam; glow.
# 2 a fine fibre.
# অংশুক (noun) piece of cloth; fine cloth.
# অংশুপট্ট (noun) silk cloth.
# অংশুময়ী (adjective) (feminine) dazzling; luminous; radiant.
# অংশুময় mas.
# অংশুমালী (noun) the sun.
# (adjective) blazing; luminous.
# অংশুল (adjective) having rays; full of rays; radiant.
# অংশুশিরা (noun) animal having arteries spread all over from one centre like the sun rays; rayed animal; the radiata.
#
#
# Bengali Word অংশ্যমানEnglish definition(adjective) in the process of being divided.
#
#
# Bengali Word অংসEnglish definition(noun) the joint by which the arms are connected with the body;  the shoulder.
# অংসকুট, অংসকূট (noun) the hunch on the shoulder of a bull; bull’s hump.
# অংসত্র (noun) protective covering for the upper part of the body worn by soldiers in former times; coat of mail.
# অংস ফলক, অংস ফলকাস্থি (noun(s)) (anatomy) the shoulder-blade; the scapula.
# অংস ভার (noun) 1 the load or burden on the shoulder.
# 2 (figurative) being accountable; duty; responsibility.
# অংসল (adjective) having massive or robust shoulders; broad-shouldered
# অংসলা (feminine)
#
#
# Bengali Word অওরত English definition[Arabic] (noun) 1 woman; 2 wife.
#
#
# Bengali Word অকচ English definition(adjective) having no or not much hair on the scalp; bald; bald-headed.
# অকচা (feminine) = অকচ .
#
#
# Bengali Word অকটুEnglish definition(adjective) not pungent or bitter; sweet.
#
#
# Bengali Word অকঠোরEnglish definition(adjective) 1 not harsh or severe; mild.
# 2 easy; simple.
#
#
# Bengali Word অকথনEnglish definition(adjective) what cannot be explained or expressed in words; inexplicable: অকথন বেদন.
# (noun) abusive, unjust or obscene utterance.
#
#
# Bengali Word অকথনীয়English definition(adjective) not proper to say; unseemly or indecent to speak.
#
#
# Bengali Word অকথাEnglish definition(noun) abusive, indecent or filthy language
# (also অকথা-কুকথা).
#
#
# Bengali Word অকথিতEnglish definition(adjective) unspoken; not pronounced, disclosed or revealed.
#
#
# Bengali Word অকথ্যEnglish definition(adjective) unutterable; unseemly or improper to say: অকথ্য খবর; beyond expression in words: অকথ্য যন্ত্রণা.
# অকথ্য-কথন (noun) improper utterance; abusive Words; revile.
# (adjective) indescribable; inexpressible.
#
#
# Bengali Word অকনিষ্ঠEnglish definition(adjective) without a younger or the youngest son/brother.
#
#
# Bengali Word অকন্টক English definition(adjective) 1 thornless; with no pricks.
# 2 (figurative) free from troubles or obstacles; safe and peaceful.
# অকণ্টকে (adverb) without let or hindrance; in peace and safety.
#
#
# Bengali Word অকপটEnglish definition(adjective) frank; open; sincere; free from angularities; candid; unreserved.
# অকপটতা (noun) frankness; candour.
# অকপটে (adverb) frankly;
# without hiding anything.
# অকপট-চিত্ত (adjective) open-hearted; simple-natured; frank.
# অকপট চিত্তে  (adverb) open heartedly; frankly; freely; sincerely.
#
#
# Bengali Word অকবজEnglish definition(adjective) not mastered; not acquired.
#
#
# Bengali Word অকবিEnglish definition(noun), (adjective) one without the genius of a poet; not fit to be called a poet.
#
#
# Bengali Word অকমনীয়English definition(adjective) 1 not to be wished for; undesirable; unwelcome.
# 2 ungraceful; uncouth; ugly.
#
#
# Bengali Word অকম্প, অকম্পিত, অকম্প্রEnglish definition(adjective) not tremulous or timorous; steady; undaunted; unmoved; unperturbed.
# অকম্পনীয় (adjective) not affected by tremors; not sensitive to shaking.
#
#
# Bengali Word অকরEnglish definition(adjective) 1 (of landed estate) rent-free; free-hold; not-liable to taxes.
# 2 having no hands; handless; armless.
# 3 without a ray of light; having no radiation.
#
#
# Bengali Word অকরণEnglish definition(noun) 1 state of being inactive; inactivity; inaction; indolence.
# 2 illegal act; improper action.
# অকরণী (noun) (mathematics) rational quantity; a quantity commensurable with natural numbers, eg, √81=9.
# অকরণীয় (adjective) what should not be done; not becoming to do.
# অকরণীয় ঘর (noun) a family not acceptable or suitable for matrimonial alliance.
#
#
# Bengali Word অকরুণEnglish definition(adjective) lacking in/not showing kindness; unkind; merciless; cruel.
