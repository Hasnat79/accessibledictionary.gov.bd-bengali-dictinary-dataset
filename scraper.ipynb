# %% [markdown]
# # Web scraper for accessibledictionary.gov.bd

# %% [markdown]
# ##### import necessary libraries

# %%
from bs4 import BeautifulSoup as bs
import requests
from tqdm import tqdm

# %% [markdown]
# #### Load "Bengali to Enlish" dictionary 1st page
# there are several pages

# %%
site="https://accessibledictionary.gov.bd/bengali-to-english/?alp=%E0%A6%85"
r=requests.get(site)

#convert to a beautiful soup object

soup = bs(r.content)

#print out the HTML

contents = soup.prettify()

print(contents)
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Bengali to English | Alphabet অ
#   </title>
#   <link href="https://accessibledictionary.gov.bd/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://accessibledictionary.gov.bd/dashboard_style.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="https://accessibledictionary.gov.bd/jquery-ui-1.10.4.custom.min.css" rel="stylesheet"/>
#   <!--[if lt IE 9]>
#  <script type="text/javascript" src="https://accessibledictionary.gov.bd/js/html5shiv.min.js"></script>
# <![endif]-->
#  </head>
#  <body>
#   <div id="wrapper">
#    <a class="sr-only" href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=%E0%A6%85#placeholder">
#     Skip to main content
#    </a>
#    <header>
#     <div class="row" id="header_home">
#      <div class="header-column-1">
#       <span id="homeIcon">
#        <a href="https://accessibledictionary.gov.bd" title="Back to Home Page">
#         <span class="sr-only">
#          Home
#         </span>
#        </a>
#       </span>
#       <h1>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english">
#         Bengali to English
#        </a>
#       </h1>
#      </div>
#      <div class="header-column-2">
#       <button id="highContrast" title="Switch to high contrast color theme">
#        High Contrast
#       </button>
#       <button class="disable" id="lowContrast" title="Switch to low contrast color theme">
#        Low Contrast
#       </button>
#      </div>
#      <div class="header-column-3">
#       <button aria-label="Increase text size" class="fontSize" id="Increase" title="Increase text size">
#        A
#        <sup>
#         +
#        </sup>
#       </button>
#       <button aria-label="Decrease text size" class="fontSize" id="Decrease" title="Decrease text size">
#        A
#        <sup>
#         -
#        </sup>
#       </button>
#      </div>
#     </div>
#    </header>
#    <!--header ends -->
#    <main id="main">
#     <div class="row block">
#      <form action="https://accessibledictionary.gov.bd/bengali-to-english/" id="homeSearch" method="get" name="homeSearch">
#       <fieldset>
#        <legend class="sr-only">
#         Search Section
#        </legend>
#        <div aria-label="Choose a keyboard layout for typing in Bengali" class="choose-keyboard" role="toolbar">
#         <a class="tooltipLink" href="https://accessibledictionary.gov.bd/help/#how-write-bengali">
#          <img alt="Help icon" aria-hidden="true" height="24" id="help" src="https://accessibledictionary.gov.bd/images/help.png" width="24"/>
#          <span class="tooltip">
#           Help: How to write Bengali?
#          </span>
#         </a>
#         <span class="kb-title">
#          কি বোর্ড বেছে নিন:
#         </span>
#         <button aria-label="Phonetic" id="phonetic" type="button">
#          ফোনেটিক
#         </button>
#         <button aria-label="Unijoy" id="unijoy" type="button">
#          ইউনিজয়
#         </button>
#         <button aria-label="English" id="Senglish" type="button">
#          English
#         </button>
#        </div>
#        <label for="autoComplete">
#         <span class="sr-only">
#          Type your word
#         </span>
#        </label>
#        <input accesskey="s" aria-live="assertive" class="searchItem" id="autoComplete" name="q" placeholder="যে শব্দটি খুঁজতে চান টাইপ করুন" required="" type="search"/>
#        <input class="button" title="Submit button" type="submit" value="Search word"/>
#       </fieldset>
#      </form>
#     </div>
#     <a class="sr-only" href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=%E0%A6%85#placeholder">
#      Skip alphabetical navigation menu.
#     </a>
#     <h2 id="alpHeading">
#      বর্ণমালা অনুক্রমে শব্দ খুঁজুন
#     </h2>
#     <nav aria-label="Alphabetical Navigation">
#      <h2 class="sr-only">
#       Browse Alphabetically
#      </h2>
#      <ul aria-label="Pages" class="alphabet">
#       <li>
#        <a class="active" href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=অ" tabindex="-1">
#         অ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=আ" tabindex="-1">
#         আ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ই" tabindex="-1">
#         ই
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঈ" tabindex="-1">
#         ঈ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=উ" tabindex="-1">
#         উ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঊ" tabindex="-1">
#         ঊ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঋ" tabindex="-1">
#         ঋ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=এ" tabindex="-1">
#         এ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঐ" tabindex="-1">
#         ঐ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ও" tabindex="-1">
#         ও
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঔ" tabindex="-1">
#         ঔ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ক" tabindex="-1">
#         ক
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=খ" tabindex="-1">
#         খ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=গ" tabindex="-1">
#         গ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঘ" tabindex="-1">
#         ঘ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঙ" tabindex="-1">
#         ঙ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=চ" tabindex="-1">
#         চ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ছ" tabindex="-1">
#         ছ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=জ" tabindex="-1">
#         জ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঝ" tabindex="-1">
#         ঝ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঞ" tabindex="-1">
#         ঞ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ট" tabindex="-1">
#         ট
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঠ" tabindex="-1">
#         ঠ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ড" tabindex="-1">
#         ড
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঢ" tabindex="-1">
#         ঢ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ণ" tabindex="-1">
#         ণ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ত" tabindex="-1">
#         ত
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=থ" tabindex="-1">
#         থ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=দ" tabindex="-1">
#         দ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ধ" tabindex="-1">
#         ধ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ন" tabindex="-1">
#         ন
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=প" tabindex="-1">
#         প
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ফ" tabindex="-1">
#         ফ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ব" tabindex="-1">
#         ব
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ভ" tabindex="-1">
#         ভ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ম" tabindex="-1">
#         ম
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=য" tabindex="-1">
#         য
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=র" tabindex="-1">
#         র
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ল" tabindex="-1">
#         ল
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=শ" tabindex="-1">
#         শ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ষ" tabindex="-1">
#         ষ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=স" tabindex="-1">
#         স
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=হ" tabindex="-1">
#         হ
#        </a>
#       </li>
#      </ul>
#     </nav>
#     <div id="placeholder">
#      <article class="dicDisplay">
#       <div class="row pageNav">
#        <div class="col-33">
#         <div class="pageNumber">
#          <span style="font-size:140%;">
#           অ
#          </span>
#          পৃষ্ঠা ১
#         </div>
#        </div>
#        <div class="col-33" style="text-align:center;">
#         <div aria-hidden="true" id="topPagination">
#          <a class="disable back" href="#" tabindex="-1">
#           আগের পৃষ্ঠা
#          </a>
#          <a href="?alp=%E0%A6%85&amp;page=2" tabindex="-1">
#           পরের পৃষ্ঠা
#          </a>
#         </div>
#        </div>
#        <div class="col-33">
#         <button aria-hidden="true" class="close closeHome" tabindex="-1" title="Close">
#          ×
#         </button>
#        </div>
#       </div>
#       <ul>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অ ১
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (noun)
#         </em>
#         the written form of the first vowel sound and 1st letter of the Bengali alphabet. Unlike other vowels অ has no shortened sign (like া ি ী). অ-আ, অ-আ-ক-খ
#         <em>
#          (noun(s))
#         </em>
#         1 the letters of the Bengali alphabet.
# 2 elementary knowledge; the rudiments of learning; ABC: ব্যাকরণের অ-আ-ক-খ.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অ ২
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (prefix)
#         </em>
#         used before
#         <em>
#          (noun(s))
#         </em>
#         ,
#         <em>
#          (adjective(s))
#         </em>
#         and (adverb(s)), it indicates negation, absence, want, shortage, contrariety,  and hostility (eg অবাঙালি, অকারণ, অযত্ন, অপরিণত, অঘাট, অধর্ম) and is equivalent to various negative prefixes in English, ie, non-, un-, il-, im-, in-, ir-, dis-, mis-, etc; when prefixed by a word beginning with a vowel, অ is replaced by অন, eg অ+অভিজ্ঞ = অনভিজ্ঞ, অ + ঐক্য=অনৈক্য, অ+ঊর্বর = অনূর্বর, etc.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অংশ
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (noun)
#         </em>
#         1 portion or piece of a whole; a section; a constituent or organic part: দেহের অর্ধাংশ (অর্ধ+অংশ); যন্ত্রের অংশ (যন্ত্রাংশ); শহরের পশ্চিমাংশ (পশ্চিম+অংশ); সমাজের বুদ্ধিজীবী অংশ, the intellectual section of the society.
# 2 an incomplete portion; a fragment or decimal fraction: ভগ্নাংশ
# (ভগ্ন+অংশ) (1/5, 0.20).
# 3 a region or geographical division: পার্বত্য অংশ.
# 4 a share or allotment: সম্পত্তির অংশ, কারবারের অংশ.
# 5 (geography) 1/360th part of the earth’s circumference; a degree: অক্ষের অংশ (অক্ষাংশ).
# 6 (astrology) 1/12th part or one of the 12 signs of the zodiac: রাশিচক্রের অংশ (রাশি).
# 7 begetting power of male deities: অবতার দেবতার অংশে জাত, an Avatara is begotten/born of a god.
# 8 incarnation or personation: বিষ্ণুর অংশ রূপে ধরাধামে আবির্ভূত, incarnation of Vishnu on earth.
# 9 point(s) of consideration; any aspect(s) of something: কোনো কোনো অংশে, in some respects.
#         <strong>
#          অংশক
#         </strong>
#         <em>
#          (noun)
#         </em>
#         (algebra) fractional part of a logarithm; a mantissa; a kinsman; a day.
#         <strong>
#          অংশ করা
#         </strong>
#         <em>
#          (verb intransitive)
#         </em>
#         ,
#         <em>
#          (verb transitive)
#         </em>
#         divide into parts or shares; distribute.
#         <strong>
#          অংশগত
#         </strong>
#         <em>
#          (adjective)
#         </em>
#         included in the rightful or inherited share; relating to a share or portion.
#         <strong>
#          অংশগ্রহণ
#         </strong>
#         <em>
#          (noun)
#         </em>
#         taking part; participation.
#         <strong>
#          অংশগ্রহণ করা
#         </strong>
#         <em>
#          (verb intransitive)
#         </em>
#         ,
#         <em>
#          (verb transitive)
#         </em>
#         take part/participate (in).
#         <strong>
#          অংশগ্রাহী
#         </strong>
#         <em>
#          (adjective)
#         </em>
#         taking a share; sharing; participating.
# 
#         <em>
#          (noun)
#         </em>
#         co-sharer; Shareholder; participant; a party.
#         <strong>
#          অংশত
#         </strong>
#         <em>
#          (adverb)
#         </em>
#         in part; partly; partially: অংশত দায়ী.
#         <strong>
#          অংশন
#         </strong>
#         <em>
#          (noun)
#         </em>
#         act of dividing/apportioning; apportionment.
#         <strong>
#          অংশনামা
#         </strong>
#         <em>
#          (noun)
#         </em>
#         a deed of partition.
#         <strong>
#          অংশনীয়
#         </strong>
#         <em>
#          (adjective)
#         </em>
#         divisible into parts or shares; to be divided.
#         <strong>
#          অংশভাগী
#         </strong>
#         <em>
#          (adjective)
#         </em>
#         having a claim to a share; entitled to a share.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অংশাংশ
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (noun)
#         </em>
#         1 fraction of a share.
#         <strong>
#         </strong>
#         2 different shares.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অংশাংশি, অংশা-অংশি
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (noun)
#         </em>
#         division into respective shares.
# 
#         <em>
#          (adverb)
#         </em>
#         according to respective shares; part by part.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অংশানো
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (verb intransitive)
#         </em>
#         <em>
#          (verb transitive)
#         </em>
#         descend/devolve on as an inheritance.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অংশিত
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         divided into parts or shares; partitioned.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অংশী
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         constituted (or composed) of parts.
# 
#         <em>
#          (noun)
#         </em>
#         1 one who shares (the sorrows of) or feels (pity for): আমার দুঃখের অংশী.
# 2 an associate in business or ownership; partner; co-sharer; shareholder; party; participant.
#         <strong>
#          অংশীদার
#         </strong>
#         <em>
#          (noun)
#         </em>
#         one having a share in a property or business.
#         <strong>
#          অংশীদারি
#         </strong>
#         <em>
#          (noun)
#         </em>
#         partnership.
# 
#         <em>
#          (adjective)
#         </em>
#         relating to partnership.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অংশু
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (noun)
#         </em>
#         1 ray of light; beam; glow.
# 2 a fine fibre.
#         <strong>
#          অংশুক
#         </strong>
#         <em>
#          (noun)
#         </em>
#         piece of cloth; fine cloth.
#         <strong>
#          অংশুপট্ট
#         </strong>
#         <em>
#          (noun)
#         </em>
#         silk cloth.
#         <strong>
#          অংশুময়ী
#         </strong>
#         <em>
#          (adjective)
#         </em>
#         (feminine) dazzling; luminous; radiant.
#         <strong>
#          অংশুময়
#         </strong>
#         mas.
#         <strong>
#          অংশুমালী
#         </strong>
#         <em>
#          (noun)
#         </em>
#         the sun.
# 
#         <em>
#          (adjective)
#         </em>
#         blazing; luminous.
#         <strong>
#          অংশুল
#         </strong>
#         <em>
#          (adjective)
#         </em>
#         having rays; full of rays; radiant.
#         <strong>
#          অংশুশিরা
#         </strong>
#         <em>
#          (noun)
#         </em>
#         animal having arteries spread all over from one centre like the sun rays; rayed animal; the radiata.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অংশ্যমান
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         in the process of being divided.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অংস
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (noun)
#         </em>
#         the joint by which the arms are connected with the body;  the shoulder.
#         <strong>
#          অংসকুট, অংসকূট
#         </strong>
#         <em>
#          (noun)
#         </em>
#         the hunch on the shoulder of a bull; bull’s hump.
#         <strong>
#          অংসত্র
#         </strong>
#         <em>
#          (noun)
#         </em>
#         protective covering for the upper part of the body worn by soldiers in former times; coat of mail.
#         <strong>
#          অংস ফলক, অংস ফলকাস্থি
#         </strong>
#         <em>
#          (noun(s))
#         </em>
#         (anatomy) the shoulder-blade; the scapula.
#         <strong>
#          অংস ভার
#         </strong>
#         <em>
#          (noun)
#         </em>
#         1 the load or burden on the shoulder.
# 2 (figurative) being accountable; duty; responsibility.
#         <strong>
#          অংসল
#         </strong>
#         <em>
#          (adjective)
#         </em>
#         having massive or robust shoulders; broad-shouldered
#         <strong>
#          অংসলা
#         </strong>
#         (feminine)
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অওরত
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         [Arabic]
#         <em>
#          (noun)
#         </em>
#         1 woman; 2 wife.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অকচ
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         having no or not much hair on the scalp; bald; bald-headed.
#         <strong>
#          অকচা
#         </strong>
#         (feminine) =
#         <a class="linkSelf" href="https://accessibledictionary.gov.bd/inc/inc_bn_en.php?q=%E0%A6%85%E0%A6%95%E0%A6%9A" rel="nofollow" tabindex="-1">
#          অকচ
#         </a>
#         .
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অকটু
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         not pungent or bitter; sweet.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অকঠোর
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         1 not harsh or severe; mild.
# 2 easy; simple.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অকথন
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         what cannot be explained or expressed in words; inexplicable: অকথন বেদন.
# 
#         <em>
#          (noun)
#         </em>
#         abusive, unjust or obscene utterance.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অকথনীয়
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         not proper to say; unseemly or indecent to speak.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অকথা
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (noun)
#         </em>
#         abusive, indecent or filthy language
# (also অকথা-কুকথা).
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অকথিত
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         unspoken; not pronounced, disclosed or revealed.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অকথ্য
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         unutterable; unseemly or improper to say: অকথ্য খবর; beyond expression in words: অকথ্য যন্ত্রণা.
#         <strong>
#          অকথ্য-কথন
#         </strong>
#         <em>
#          (noun)
#         </em>
#         improper utterance; abusive Words; revile.
# 
#         <em>
#          (adjective)
#         </em>
#         indescribable; inexpressible.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অকনিষ্ঠ
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         without a younger or the youngest son/brother.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অকন্টক
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         1 thornless; with no pricks.
# 2 (figurative) free from troubles or obstacles; safe and peaceful.
#         <strong>
#          অকণ্টকে
#         </strong>
#         <em>
#          (adverb)
#         </em>
#         without let or hindrance; in peace and safety.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অকপট
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         frank; open; sincere; free from angularities; candid; unreserved.
#         <strong>
#          অকপটতা
#         </strong>
#         <em>
#          (noun)
#         </em>
#         frankness; candour.
#         <strong>
#          অকপটে
#         </strong>
#         <em>
#          (adverb)
#         </em>
#         frankly;
# without hiding anything.
#         <strong>
#          অকপট-চিত্ত
#         </strong>
#         <em>
#          (adjective)
#         </em>
#         open-hearted; simple-natured; frank.
#         <strong>
#          অকপট চিত্তে
#         </strong>
#         <em>
#          (adverb)
#         </em>
#         open heartedly; frankly; freely; sincerely.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অকবজ
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         not mastered; not acquired.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অকবি
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (noun)
#         </em>
#         ,
#         <em>
#          (adjective)
#         </em>
#         one without the genius of a poet; not fit to be called a poet.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অকমনীয়
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         1 not to be wished for; undesirable; unwelcome.
# 2 ungraceful; uncouth; ugly.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অকম্প, অকম্পিত, অকম্প্র
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         not tremulous or timorous; steady; undaunted; unmoved; unperturbed.
#         <strong>
#          অকম্পনীয়
#         </strong>
#         <em>
#          (adjective)
#         </em>
#         not affected by tremors; not sensitive to shaking.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অকর
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         1 (of landed estate) rent-free; free-hold; not-liable to taxes.
# 2 having no hands; handless; armless.
# 3 without a ray of light; having no radiation.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অকরণ
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (noun)
#         </em>
#         1 state of being inactive; inactivity; inaction; indolence.
# 2 illegal act; improper action.
#         <strong>
#          অকরণী
#         </strong>
#         <em>
#          (noun)
#         </em>
#         (mathematics) rational quantity; a quantity commensurable with natural numbers, eg, √81=9.
#         <strong>
#          অকরণীয়
#         </strong>
#         <em>
#          (adjective)
#         </em>
#         what should not be done; not becoming to do.
#         <strong>
#          অকরণীয় ঘর
#         </strong>
#         <em>
#          (noun)
#         </em>
#         a family not acceptable or suitable for matrimonial alliance.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          অকরুণ
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         lacking in/not showing kindness; unkind; merciless; cruel.
#        </li>
#       </ul>
#      </article>
#      <nav aria-label="Pages" class="row" id="pagination">
#       <h2 class="sr-only">
#        Browse pages by numbers.
#       </h2>
#       <ul class="pagination">
#        <li>
#         <a href="?alp=অ&amp;page=2">
#          Next Page »
#         </a>
#        </li>
#        <li>
#         <span class="current">
#          <span class="sr-only">
#           current page
#          </span>
#          1
#         </span>
#        </li>
#        <li>
#         <a aria-label="Page 2" href="?alp=অ&amp;page=2" tabindex="-1">
#          2
#         </a>
#        </li>
#        <li>
#         <a aria-label="Page 3" href="?alp=অ&amp;page=3" tabindex="-1">
#          3
#         </a>
#        </li>
#        <li>
#         <a aria-label="Page 4" href="?alp=অ&amp;page=4" tabindex="-1">
#          4
#         </a>
#        </li>
#        <li>
#         <a aria-label="Page 5" href="?alp=অ&amp;page=5" tabindex="-1">
#          5
#         </a>
#        </li>
#        <li>
#         <a aria-label="Page 6" href="?alp=অ&amp;page=6" tabindex="-1">
#          6
#         </a>
#        </li>
#        <li>
#         <a aria-label="Page 7" href="?alp=অ&amp;page=7" tabindex="-1">
#          7
#         </a>
#        </li>
#        <li>
#         <a aria-label="Page 8" href="?alp=অ&amp;page=8" tabindex="-1">
#          8
#         </a>
#        </li>
#        <li>
#         <a aria-label="Page 9" href="?alp=অ&amp;page=9" tabindex="-1">
#          9
#         </a>
#        </li>
#        <li>
#         ...
#        </li>
#        <li>
#         <a aria-label="Page 46" href="?alp=অ&amp;page=46" tabindex="-1">
#          46
#         </a>
#        </li>
#        <li>
#         <a aria-label="Page 47" href="?alp=অ&amp;page=47" tabindex="-1">
#          47
#         </a>
#        </li>
#        <li>
#         <a aria-label="Last Page 48" href="?alp=অ&amp;page=48" tabindex="-1">
#          48
#         </a>
#        </li>
#        <li aria-disabled="true">
#         <span class="disabled">
#          « Previous Page
#         </span>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </main>
#   </div>
#   <!--end of wrapper -->
#   <nav aria-label="Site Navigation" id="siteNav">
#    <ul id="menu">
#     <li>
#      <a accesskey="h" href="https://accessibledictionary.gov.bd">
#       Home
#      </a>
#     </li>
#     <li>
#      <a aria-label="Current Page" class="active" href="https://accessibledictionary.gov.bd/bengali-to-english/">
#       Bengali to English
#      </a>
#     </li>
#     <li>
#      <a href="https://accessibledictionary.gov.bd/english-to-bengali/">
#       English to Bengali
#      </a>
#     </li>
#     <li>
#      <a href="https://accessibledictionary.gov.bd/bengali-to-bengali/">
#       Bengali to Bengali
#      </a>
#     </li>
#     <li>
#      <a href="https://accessibledictionary.gov.bd/english-to-english/">
#       English to English
#      </a>
#     </li>
#     <li>
#      <a href="https://accessibledictionary.gov.bd/help/">
#       Help
#      </a>
#     </li>
#     <li>
#      <a href="https://accessibledictionary.gov.bd/accessibility/">
#       Accessibility Statement
#      </a>
#     </li>
#    </ul>
#   </nav>
#   <footer>
#    <div id="footerWrapper">
#     <div class="fotter-col-1">
#      Developed by
#      <a href="http://ypsa.org" target="_blank" title="Opens in new window">
#       YPSA
#      </a>
#      and supported by
#      <a href="http://a2i.pmo.gov.bd/" target="_blank" title="Opens in new window">
#       Acces to Information Program (a2i)
#      </a>
#      ,
#      <br/>
#      Prime Minister Office, Bangladesh
#      <div class="row">
#       <img alt="Logos of Bangladesh Government, A2I program, YPSA and U N D P." height="85" src="../images/logos.png" style="padding-top:15px;" width="470"/>
#      </div>
#     </div>
#     <div class="fotter-col-2">
#      <ul>
#       <li style="background:url(https://accessibledictionary.gov.bd/images/icon-desktop.png)left no-repeat;">
#        <a href="Accesible-dic-Desktop-version-1.zip">
#         Download Dictionary (Desktop Version)
#        </a>
#       </li>
#       <li style="background:url(https://accessibledictionary.gov.bd/images/icon-phone.png)left no-repeat;">
#        <a href="https://play.google.com/store/apps/details?id=com.programextended.www.accessibledictionaryoffline">
#         Install Android mobile App from Google Play Store
#        </a>
#       </li>
#       <li style="background:url(https://accessibledictionary.gov.bd/images/icon-eye.png)left no-repeat;">
#        <a href="https://www.nvaccess.org/download/" target="_blank" title="Opens in new window">
#         Download NVDA (Screen Reading Software)
#        </a>
#       </li>
#       <li style="background:url(https://accessibledictionary.gov.bd/images/icon-people.png)left no-repeat;">
#        <a href="https://accessibledictionary.gov.bd/about">
#         About this Dictionary
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </footer>
#   <script src="https://accessibledictionary.gov.bd/js/jquery-1.11.0.min.js">
#   </script>
#   <script src="https://accessibledictionary.gov.bd/js/jquery_cookie.js">
#   </script>
#   <script src="https://accessibledictionary.gov.bd/js/custom.js">
#   </script>
#   <script src="https://accessibledictionary.gov.bd/js/board.js">
#   </script>
#   <script src="https://accessibledictionary.gov.bd/js/jquery-ui-1.10.4.custom.min.js">
#   </script>
#   <script src="https://accessibledictionary.gov.bd/js/voice.js">
#   </script>
#   <script>
#    $(function() {
#     $( "#autoComplete" ).autocomplete({
#         source: 'https://accessibledictionary.gov.bd/inc/search_autoComplete_bn_to_en.php',
# 		minLength: 3,
# 		delay: 800,
# 		messages: {
#         noResults: '',
# 		results : function(count) {}
# 		},
# 		select: function(event, ui) {
#         //assign value back to the form element
#         if(ui.item){
#             $(event.target).val(ui.item.value);
#         }
#         //submit the form
#         $(event.target.form).submit();
#     	}
#     });
#
# //alert($.cookie('keyBoard'));
# 		$('#placeholder').attr('tabindex','0').focus();
# 	});
#   </script>
#  </body>
# </html>

# %% [markdown]
# ##### Getting all the link of all the banlga alphabets from অ to হ

# %%
alphabet_links=[]
alphabet_box =soup.find(class_="alphabet")
alphs=alphabet_box.find_all('a')
for index,row in enumerate(alphs):
    link=row.get('href')
#     print(link)
    alphabet_links.append(link)

alphabet_links
# Out:
# ['https://accessibledictionary.gov.bd/bengali-to-english/?alp=অ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=আ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ই',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঈ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=উ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঊ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঋ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=এ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঐ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ও',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঔ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ক',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=খ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=গ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঘ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঙ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=চ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ছ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=জ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঝ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঞ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ট',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঠ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ড',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঢ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ণ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ত',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=থ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=দ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ধ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ন',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=প',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ফ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ব',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ভ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ম',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=য',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=র',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ল',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=শ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ষ',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=স',
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=হ']

# %% [markdown]
# ##### getting page numbers for each alphabet

# %%
''' alph_and_page_numbers_info dictionary 
    key= link of each alphabet
    value= number of pages available for that alphabet(int)
'''
alph_and_page_numbers_info={}

# pagitation_box=soup.find(class_="pagination")
# page_numbers=pagitation_box.find_all('li')
# page_numbers[-2].get_text()
for index,link in enumerate(alphabet_links):
    r=requests.get(link)
    soup = bs(r.content)
    
    if soup.find(class_="pagination"):
        
        pagitation_box=soup.find(class_="pagination")
        page_numbers=pagitation_box.find_all('li')

        no_of_pages=int(page_numbers[-2].get_text())
    else:
        no_of_pages=1
    alph_and_page_numbers_info [link] =no_of_pages
    
    print(f"Case no: {index}: done")
    
alph_and_page_numbers_info
# Out:
# Case no: 0: done
# Case no: 1: done
# Case no: 2: done
# Case no: 3: done
# Case no: 4: done
# Case no: 5: done
# Case no: 6: done
# Case no: 7: done
# Case no: 8: done
# Case no: 9: done
# Case no: 10: done
# Case no: 11: done
# Case no: 12: done
# Case no: 13: done
# Case no: 14: done
# Case no: 15: done
# Case no: 16: done
# Case no: 17: done
# Case no: 18: done
# Case no: 19: done
# Case no: 20: done
# Case no: 21: done
# Case no: 22: done
# Case no: 23: done
# Case no: 24: done
# Case no: 25: done
# Case no: 26: done
# Case no: 27: done
# Case no: 28: done
# Case no: 29: done
# Case no: 30: done
# Case no: 31: done
# Case no: 32: done
# Case no: 33: done
# Case no: 34: done
# Case no: 35: done
# Case no: 36: done
# Case no: 37: done
# Case no: 38: done
# Case no: 39: done
# Case no: 40: done
# Case no: 41: done
# Case no: 42: done
# {'https://accessibledictionary.gov.bd/bengali-to-english/?alp=অ': 48,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=আ': 30,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ই': 7,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঈ': 1,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=উ': 16,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঊ': 1,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঋ': 1,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=এ': 13,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঐ': 1,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ও': 3,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঔ': 1,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ক': 46,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=খ': 11,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=গ': 18,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঘ': 6,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঙ': 1,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=চ': 19,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ছ': 8,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=জ': 26,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঝ': 5,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঞ': 1,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ট': 6,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঠ': 3,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ড': 4,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঢ': 3,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ণ': 1,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ত': 27,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=থ': 2,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=দ': 33,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ধ': 11,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ন': 44,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=প': 100,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ফ': 14,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ব': 86,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ভ': 23,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ম': 49,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=য': 10,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=র': 21,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ল': 17,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=শ': 25,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=ষ': 1,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=স': 87,
#  'https://accessibledictionary.gov.bd/bengali-to-english/?alp=হ': 22}

# %% [markdown]
# ##### Getting contents for a single alphabet

# %%
alph=alphabet_links[1][-1]
print(alph)
page=2


site=f"https://accessibledictionary.gov.bd/bengali-to-english/?alp={alph}&page={page}"

r=requests.get(site)
soup = bs(r.content)

contents=soup.prettify()
print(contents)
# Out:
# আ
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Bengali to English | Alphabet আ | Page 2
#   </title>
#   <link href="https://accessibledictionary.gov.bd/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://accessibledictionary.gov.bd/dashboard_style.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="https://accessibledictionary.gov.bd/jquery-ui-1.10.4.custom.min.css" rel="stylesheet"/>
#   <!--[if lt IE 9]>
#  <script type="text/javascript" src="https://accessibledictionary.gov.bd/js/html5shiv.min.js"></script>
# <![endif]-->
#  </head>
#  <body>
#   <div id="wrapper">
#    <a class="sr-only" href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=%E0%A6%86&amp;page=2#placeholder">
#     Skip to main content
#    </a>
#    <header>
#     <div class="row" id="header_home">
#      <div class="header-column-1">
#       <span id="homeIcon">
#        <a href="https://accessibledictionary.gov.bd" title="Back to Home Page">
#         <span class="sr-only">
#          Home
#         </span>
#        </a>
#       </span>
#       <h1>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english">
#         Bengali to English
#        </a>
#       </h1>
#      </div>
#      <div class="header-column-2">
#       <button id="highContrast" title="Switch to high contrast color theme">
#        High Contrast
#       </button>
#       <button class="disable" id="lowContrast" title="Switch to low contrast color theme">
#        Low Contrast
#       </button>
#      </div>
#      <div class="header-column-3">
#       <button aria-label="Increase text size" class="fontSize" id="Increase" title="Increase text size">
#        A
#        <sup>
#         +
#        </sup>
#       </button>
#       <button aria-label="Decrease text size" class="fontSize" id="Decrease" title="Decrease text size">
#        A
#        <sup>
#         -
#        </sup>
#       </button>
#      </div>
#     </div>
#    </header>
#    <!--header ends -->
#    <main id="main">
#     <div class="row block">
#      <form action="https://accessibledictionary.gov.bd/bengali-to-english/" id="homeSearch" method="get" name="homeSearch">
#       <fieldset>
#        <legend class="sr-only">
#         Search Section
#        </legend>
#        <div aria-label="Choose a keyboard layout for typing in Bengali" class="choose-keyboard" role="toolbar">
#         <a class="tooltipLink" href="https://accessibledictionary.gov.bd/help/#how-write-bengali">
#          <img alt="Help icon" aria-hidden="true" height="24" id="help" src="https://accessibledictionary.gov.bd/images/help.png" width="24"/>
#          <span class="tooltip">
#           Help: How to write Bengali?
#          </span>
#         </a>
#         <span class="kb-title">
#          কি বোর্ড বেছে নিন:
#         </span>
#         <button aria-label="Phonetic" id="phonetic" type="button">
#          ফোনেটিক
#         </button>
#         <button aria-label="Unijoy" id="unijoy" type="button">
#          ইউনিজয়
#         </button>
#         <button aria-label="English" id="Senglish" type="button">
#          English
#         </button>
#        </div>
#        <label for="autoComplete">
#         <span class="sr-only">
#          Type your word
#         </span>
#        </label>
#        <input accesskey="s" aria-live="assertive" class="searchItem" id="autoComplete" name="q" placeholder="যে শব্দটি খুঁজতে চান টাইপ করুন" required="" type="search"/>
#        <input class="button" title="Submit button" type="submit" value="Search word"/>
#       </fieldset>
#      </form>
#     </div>
#     <a class="sr-only" href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=%E0%A6%86&amp;page=2#placeholder">
#      Skip alphabetical navigation menu.
#     </a>
#     <h2 id="alpHeading">
#      বর্ণমালা অনুক্রমে শব্দ খুঁজুন
#     </h2>
#     <nav aria-label="Alphabetical Navigation">
#      <h2 class="sr-only">
#       Browse Alphabetically
#      </h2>
#      <ul aria-label="Pages" class="alphabet">
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=অ" tabindex="-1">
#         অ
#        </a>
#       </li>
#       <li>
#        <a class="active" href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=আ" tabindex="-1">
#         আ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ই" tabindex="-1">
#         ই
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঈ" tabindex="-1">
#         ঈ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=উ" tabindex="-1">
#         উ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঊ" tabindex="-1">
#         ঊ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঋ" tabindex="-1">
#         ঋ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=এ" tabindex="-1">
#         এ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঐ" tabindex="-1">
#         ঐ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ও" tabindex="-1">
#         ও
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঔ" tabindex="-1">
#         ঔ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ক" tabindex="-1">
#         ক
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=খ" tabindex="-1">
#         খ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=গ" tabindex="-1">
#         গ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঘ" tabindex="-1">
#         ঘ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঙ" tabindex="-1">
#         ঙ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=চ" tabindex="-1">
#         চ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ছ" tabindex="-1">
#         ছ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=জ" tabindex="-1">
#         জ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঝ" tabindex="-1">
#         ঝ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঞ" tabindex="-1">
#         ঞ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ট" tabindex="-1">
#         ট
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঠ" tabindex="-1">
#         ঠ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ড" tabindex="-1">
#         ড
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ঢ" tabindex="-1">
#         ঢ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ণ" tabindex="-1">
#         ণ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ত" tabindex="-1">
#         ত
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=থ" tabindex="-1">
#         থ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=দ" tabindex="-1">
#         দ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ধ" tabindex="-1">
#         ধ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ন" tabindex="-1">
#         ন
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=প" tabindex="-1">
#         প
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ফ" tabindex="-1">
#         ফ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ব" tabindex="-1">
#         ব
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ভ" tabindex="-1">
#         ভ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ম" tabindex="-1">
#         ম
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=য" tabindex="-1">
#         য
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=র" tabindex="-1">
#         র
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ল" tabindex="-1">
#         ল
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=শ" tabindex="-1">
#         শ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=ষ" tabindex="-1">
#         ষ
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=স" tabindex="-1">
#         স
#        </a>
#       </li>
#       <li>
#        <a href="https://accessibledictionary.gov.bd/bengali-to-english/?alp=হ" tabindex="-1">
#         হ
#        </a>
#       </li>
#      </ul>
#     </nav>
#     <div id="placeholder">
#      <article class="dicDisplay">
#       <div class="row pageNav">
#        <div class="col-33">
#         <div class="pageNumber">
#          <span style="font-size:140%;">
#           আ
#          </span>
#          পৃষ্ঠা ২
#         </div>
#        </div>
#        <div class="col-33" style="text-align:center;">
#         <div aria-hidden="true" id="topPagination">
#          <a class="back" href="?alp=%E0%A6%86&amp;page=1" rel="nofollow" tabindex="-1">
#           আগের পৃষ্ঠা
#          </a>
#          <a href="?alp=%E0%A6%86&amp;page=3" tabindex="-1">
#           পরের পৃষ্ঠা
#          </a>
#         </div>
#        </div>
#        <div class="col-33">
#         <button aria-hidden="true" class="close closeHome" tabindex="-1" title="Close">
#          ×
#         </button>
#        </div>
#       </div>
#       <ul>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আংটি
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (noun)
#         </em>
#         finger ring; ornamental ring for finger.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আংশিক
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         partial; relating to a part/ share.
#         <strong>
#          আংশিক রূপে
#         </strong>
#         <em>
#          (adverb)
#         </em>
#         in part; partially.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আঃ ১, আহ্‌
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (interjection)
#         </em>
#         expressing surprise, anger, irritation, vexation, grief, relief, etc.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আঃ ২
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (noun)
#         </em>
#         abbreviation of the phrase “আলাইহিস্‌ সালাম” ie, “peace be on him” expressed or used after the names of prophets.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আইন
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         [Persian]
#         <em>
#          (noun)
#         </em>
#         law; the body of rules established and administered by authority; any of those rules; an act; a statute; an ordinance.
#         <strong>
#          আইন করা
#         </strong>
#         <em>
#          (verb intransitive)
#         </em>
#         legislate; enact a law; make a rule.
#         <strong>
#          দেওয়ানি আইন
#         </strong>
#         noun civil law.
#         <strong>
#          ফৌজদারি আইন
#         </strong>
#         noun criminal law.
#         <strong>
#          সামরিক আইন
#         </strong>
#         noun martial law.
#         <strong>
#          আইন-কানুন
#         </strong>
#         noun [Persian + Arabic] rules and regulations.
#         <strong>
#          আইনকার, আইনকর্তা
#         </strong>
#         <em>
#          (noun)
#         </em>
#         legislator; law-giver.
#         <strong>
#          আইনগত
#         </strong>
#         <em>
#          (adjective)
#         </em>
#         legal; statutory.
#         <strong>
#          আইনজীবী, আইন ব্যবসায়ী
#         </strong>
#         <em>
#          (noun)
#         </em>
#         a legal practitioner; a lawyer; a pleader; an advocate; a barrister; an attorney; a solicitor.
#         <strong>
#          আইনজ্ঞ
#         </strong>
#         adjective versed in law.
# 
#         <em>
#          (noun)
#         </em>
#         a jurist.
#         <strong>
#          আইনত
#         </strong>
#         <em>
#          (adverb)
#         </em>
#         legally; according to law.
#         <strong>
#          আইন পরিষদ
#         </strong>
#         noun legislative assembly; a legislature.
#         <strong>
#          আইন পেশা
#         </strong>
#         <em>
#          (noun)
#         </em>
#         legal profession.
#         <strong>
#          আইন প্রণয়ন
#         </strong>
#         <em>
#          (noun)
#         </em>
#         enactment of laws; legislation.
#         <strong>
#          আইনমাফিক, আইন মোতাবেক
#         </strong>
#         adjective lawful; legitimate.
# 
#         <em>
#          (adverb)
#         </em>
#         legally; according to law.
#         <strong>
#          আইন শাস্ত্র
#         </strong>
#         <em>
#          (noun)
#         </em>
#         the science or knowledge at law; jurisprudence.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আইবুড়ো
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         unmarried.
#         <strong>
#          আইবুড়ো মেয়ে
#         </strong>
#         <em>
#          (noun)
#         </em>
#         spinster.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আইস ১
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         =
#         <a class="linkSelf" href="https://accessibledictionary.gov.bd/inc/inc_bn_en.php?q=%E0%A6%86%E0%A6%81%E0%A6%B6%20%E0%A7%A7" rel="nofollow" tabindex="-1">
#          আঁশ ১
#         </a>
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আইয়াম, আয়াম
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         [Arabic]
#         <em>
#          (noun)
#         </em>
#         1 the days.
# 2 time; season.
# 3 proper time; opportune moment.
#         <strong>
#          আইয়ামবেজ, আইয়ামবীজ
#         </strong>
#         <em>
#          (noun)
#         </em>
#         the bright fortnight days; the 13th, 14th and 15th  day of lunar months.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আউওল
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         [Arabic]
#         <em>
#          (adjective)
#         </em>
#         1 first; original.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আউলা
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         (colloquial) untidy; dishevelled; (also আউলা ঝাউলা).
#         <strong>
#          আউলানো
#         </strong>
#         <em>
#          (verb transitive)
#         </em>
#         (of hair and clothes) dishevel.
# 
#         <em>
#          (adjective)
#         </em>
#         disheveled; untidy.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আউলিয়া, আওলিয়া
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         [Arabic]
#         <em>
#          (noun)
#         </em>
#         a Muslim saint.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আউশ
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (noun)
#         </em>
#         variety of paddy harvested in the rainy season.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আউয়াল, আউওল
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         [Arabic]
#         <em>
#          (adjective)
#         </em>
#         1 first; original.
# 2 best; excellent.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আওতা ১
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (noun)
#         </em>
#         shade; sunshade.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আওতা ২
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         1 influence.
# 2 guardianship; custody; control.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আওতা ৩
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (noun)
#         </em>
#         jurisdiction; purview.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আওরত, আউরত
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         [Arabic]
#         <em>
#          (noun)
#         </em>
#         1 woman;
# 2 wife.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আওলাদ, আউলাদ
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         [Arabic]
#         <em>
#          (noun)
#         </em>
#         children; offspring; progeny.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আওলিয়া
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         [Arabic]
#         <em>
#          (noun)
#         </em>
#         a Muslim saint.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আওড়ানো
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <strong>
#         </strong>
#         <em>
#          (verb intransitive)
#         </em>
#         ,
#         <em>
#          (verb transitive)
#         </em>
#         pronounce; recite; chant.
# 
#         <em>
#          (noun)
#         </em>
#         repeated pronouncement or recitation.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আওয়াজ
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         [Persian]
#         <em>
#          (noun)
#         </em>
#         1 sound; noise.
# 2 voice.
#         <strong>
#          আওয়াজ তোলা
#         </strong>
#         <em>
#          (verb intransitive)
#         </em>
#         ,
#         <em>
#          (verb transitive)
#         </em>
#         raise voice.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আকণ্ঠ
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adverb)
#         </em>
#         1 upto the throat.
# 2 in full; completely.
#         <strong>
#          আকণ্ঠ ভোজন
#         </strong>
#         <em>
#          (noun)
#         </em>
#         voracious eating; surfeit.
#         <strong>
#          আকণ্ঠ ভোজন করা
#         </strong>
#         <em>
#          (verb transitive)
#         </em>
#         eat to excess.
#         <strong>
#          আকণ্ঠ নিমজ্জিত
#         </strong>
#         <em>
#          (adverb)
#         </em>
#         almost submerged: তিনি ঋণে আকণ্ঠ নিমজ্জিত, He is over head and ears in debt.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আকথা-কুকথা
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (noun)
#         </em>
#         slang words; ominous talk.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আকনি
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (noun)
#         </em>
#         solution prepared by boiling water with spices for cooking 'pilau'.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আকন্দ
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (noun)
#         </em>
#         sun-plant; swallow-wort.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আকবর
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         [Arabic]
#         <em>
#          (adjective)
#         </em>
#         the great; almighty.
# 
#         <em>
#          (noun)
#         </em>
#         Akbar; the Great Mughal emperor.
#         <strong>
#          আকবরি
#         </strong>
#         <em>
#          (adjective)
#         </em>
#         of emperor Akbar or his reign.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আকর
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (noun)
#         </em>
#         1 a mine; a quarry.
# 2 (figurative) rich or abundant source. জ্ঞানের আকর.
#         <strong>
#          আকরিক
#         </strong>
#         <em>
#          (adjective)
#         </em>
#         1 of mines; mineral.
# 2 relating to source: আকরিক গ্রন্থ.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আকর্ণ
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adverb)
#         </em>
#         upto the ear; as far as the ear.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আকর্ষণ
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (noun)
#         </em>
#         attraction.
#         <strong>
#          আকর্ষণ করা
#         </strong>
#         <em>
#          (verb transitive)
#         </em>
#         attract; draw; pull.
#         <strong>
#          আকর্ষণী শক্তি
#         </strong>
#         <em>
#          (noun)
#         </em>
#         power of attraction; magnetism.
#         <strong>
#          আকর্ষণীয়
#         </strong>
#         <em>
#          (adjective)
#         </em>
#         attractive.
#        </li>
#        <li>
#         <span class="sr-only">
#          Bengali Word
#         </span>
#         <span class="separator">
#          আকস্মিক
#         </span>
#         <span class="sr-only">
#          English definition
#         </span>
#         <em>
#          (adjective)
#         </em>
#         sudden; unexpected; accidental.
#         <strong>
#          আকস্মিক ঘটনা
#         </strong>
#         <em>
#          (noun)
#         </em>
#         chance; occurrence; accident.
#         <strong>
#          আকস্মিক দুর্ঘটনা
#         </strong>
#         <em>
#          (noun)
#         </em>
#         mishap; accident.
#        </li>
#       </ul>
#      </article>
#      <nav aria-label="Pages" class="row" id="pagination">
#       <h2 class="sr-only">
#        Browse pages by numbers.
#       </h2>
#       <ul class="pagination">
#        <li>
#         <a href="?alp=আ&amp;page=3">
#          Next Page »
#         </a>
#        </li>
#        <li>
#         <a aria-label="Page 1" href="?alp=আ&amp;page=1" tabindex="-1">
#          1
#         </a>
#        </li>
#        <li>
#         <span class="current">
#          <span class="sr-only">
#           current page
#          </span>
#          2
#         </span>
#        </li>
#        <li>
#         <a aria-label="Page 3" href="?alp=আ&amp;page=3" tabindex="-1">
#          3
#         </a>
#        </li>
#        <li>
#         <a aria-label="Page 4" href="?alp=আ&amp;page=4" tabindex="-1">
#          4
#         </a>
#        </li>
#        <li>
#         <a aria-label="Page 5" href="?alp=আ&amp;page=5" tabindex="-1">
#          5
#         </a>
#        </li>
#        <li>
#         <a aria-label="Page 6" href="?alp=আ&amp;page=6" tabindex="-1">
#          6
#         </a>
#        </li>
#        <li>
#         <a aria-label="Page 7" href="?alp=আ&amp;page=7" tabindex="-1">
#          7
#         </a>
#        </li>
#        <li>
#         <a aria-label="Page 8" href="?alp=আ&amp;page=8" tabindex="-1">
#          8
#         </a>
#        </li>
#        <li>
#         <a aria-label="Page 9" href="?alp=আ&amp;page=9" tabindex="-1">
#          9
#         </a>
#        </li>
#        <li>
#         ...
#        </li>
#        <li>
#         <a aria-label="Page 28" href="?alp=আ&amp;page=28" tabindex="-1">
#          28
#         </a>
#        </li>
#        <li>
#         <a aria-label="Page 29" href="?alp=আ&amp;page=29" tabindex="-1">
#          29
#         </a>
#        </li>
#        <li>
#         <a aria-label="Last Page 30" href="?alp=আ&amp;page=30" tabindex="-1">
#          30
#         </a>
#        </li>
#        <li>
#         <a href="?alp=আ&amp;page=1">
#          « Previous Page
#         </a>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </main>
#   </div>
#   <!--end of wrapper -->
#   <nav aria-label="Site Navigation" id="siteNav">
#    <ul id="menu">
#     <li>
#      <a accesskey="h" href="https://accessibledictionary.gov.bd">
#       Home
#      </a>
#     </li>
#     <li>
#      <a aria-label="Current Page" class="active" href="https://accessibledictionary.gov.bd/bengali-to-english/">
#       Bengali to English
#      </a>
#     </li>
#     <li>
#      <a href="https://accessibledictionary.gov.bd/english-to-bengali/">
#       English to Bengali
#      </a>
#     </li>
#     <li>
#      <a href="https://accessibledictionary.gov.bd/bengali-to-bengali/">
#       Bengali to Bengali
#      </a>
#     </li>
#     <li>
#      <a href="https://accessibledictionary.gov.bd/english-to-english/">
#       English to English
#      </a>
#     </li>
#     <li>
#      <a href="https://accessibledictionary.gov.bd/help/">
#       Help
#      </a>
#     </li>
#     <li>
#      <a href="https://accessibledictionary.gov.bd/accessibility/">
#       Accessibility Statement
#      </a>
#     </li>
#    </ul>
#   </nav>
#   <footer>
#    <div id="footerWrapper">
#     <div class="fotter-col-1">
#      Developed by
#      <a href="http://ypsa.org" target="_blank" title="Opens in new window">
#       YPSA
#      </a>
#      and supported by
#      <a href="http://a2i.pmo.gov.bd/" target="_blank" title="Opens in new window">
#       Acces to Information Program (a2i)
#      </a>
#      ,
#      <br/>
#      Prime Minister Office, Bangladesh
#      <div class="row">
#       <img alt="Logos of Bangladesh Government, A2I program, YPSA and U N D P." height="85" src="../images/logos.png" style="padding-top:15px;" width="470"/>
#      </div>
#     </div>
#     <div class="fotter-col-2">
#      <ul>
#       <li style="background:url(https://accessibledictionary.gov.bd/images/icon-desktop.png)left no-repeat;">
#        <a href="Accesible-dic-Desktop-version-1.zip">
#         Download Dictionary (Desktop Version)
#        </a>
#       </li>
#       <li style="background:url(https://accessibledictionary.gov.bd/images/icon-phone.png)left no-repeat;">
#        <a href="https://play.google.com/store/apps/details?id=com.programextended.www.accessibledictionaryoffline">
#         Install Android mobile App from Google Play Store
#        </a>
#       </li>
#       <li style="background:url(https://accessibledictionary.gov.bd/images/icon-eye.png)left no-repeat;">
#        <a href="https://www.nvaccess.org/download/" target="_blank" title="Opens in new window">
#         Download NVDA (Screen Reading Software)
#        </a>
#       </li>
#       <li style="background:url(https://accessibledictionary.gov.bd/images/icon-people.png)left no-repeat;">
#        <a href="https://accessibledictionary.gov.bd/about">
#         About this Dictionary
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </footer>
#   <script src="https://accessibledictionary.gov.bd/js/jquery-1.11.0.min.js">
#   </script>
#   <script src="https://accessibledictionary.gov.bd/js/jquery_cookie.js">
#   </script>
#   <script src="https://accessibledictionary.gov.bd/js/custom.js">
#   </script>
#   <script src="https://accessibledictionary.gov.bd/js/board.js">
#   </script>
#   <script src="https://accessibledictionary.gov.bd/js/jquery-ui-1.10.4.custom.min.js">
#   </script>
#   <script src="https://accessibledictionary.gov.bd/js/voice.js">
#   </script>
#   <script>
#    $(function() {
#     $( "#autoComplete" ).autocomplete({
#         source: 'https://accessibledictionary.gov.bd/inc/search_autoComplete_bn_to_en.php',
# 		minLength: 3,
# 		delay: 800,
# 		messages: {
#         noResults: '',
# 		results : function(count) {}
# 		},
# 		select: function(event, ui) {
#         //assign value back to the form element
#         if(ui.item){
#             $(event.target).val(ui.item.value);
#         }
#         //submit the form
#         $(event.target.form).submit();
#     	}
#     });
#
# //alert($.cookie('keyBoard'));
# 		$('#placeholder').attr('tabindex','0').focus();
# 	});
#   </script>
#  </body>
# </html>
